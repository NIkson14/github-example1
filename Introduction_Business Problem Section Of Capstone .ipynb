# %% [markdown]
# # Introduction: Business Problem

# %% [markdown]
# In this project I will try to find an optimal housing loction near boston metropolitian college . Specifically, this report will be targeted to foregin students coming in for grad and post grad .
# Since there is a lot of housing area in boston area, I am particularly interested in areas with that along with being close to school, it would be close to other facilities  which are hospitals, supermarkets, eateries, transportation;  assuming that housing prices are more or less constant.
# We will use our data science powers to generate a few most promissing neighborhoods based on this criteria. Advantages of each area will then be clearly expressed so that best possible final location can be chosen by students.
